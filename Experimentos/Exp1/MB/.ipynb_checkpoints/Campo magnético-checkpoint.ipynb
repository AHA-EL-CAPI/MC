# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
# %matplotlib inline

# %%
plt.figure()
x_m = np.array([2.3*10**(-2),2.8*10**(-2),3.2*10**(-2),3.7*10**(-2),4.3*10**(-2)])
B_T = np.array([34745*10**(-6),19689*10**(-6),12594*10**(-6),7982*10**(-6),5822*10**(-6)])
plt.plot(x_m,B_uT,'bo', label='Datos')

u_0 = 10**(-7)
def B(r,m):
    return (u_0)*(2*m/r**3)

nonlfit,cov = curve_fit(B, x_m, B_T)
new_x = np.linspace(2.0*10**(-2),4.5*10**(-2),100)
y = B(new_x, *nonlfit)
plt.plot(new_x,y, label='Ajuste')

plt.legend(loc='best')
plt.show()
print 'El momento magnético dipolar es: ' + str(nonlfit[0]) + ' A m²'
# Out:
# El momento magnético dipolar es: 2.11829496309 A m²
