# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import matplotlib.animation as animation

# %%
# %matplotlib inline
alpha = 5.
times=np.linspace(0,1.,100000)
def f(Y,t):
    return np.array([Y[1],-alpha*np.cos(Y[0])*Y[1]]) 


funsol,others=odeint(f,[0.,1.],times,full_output=True)

plt.figure(figsize=(15,10))
plt.plot(times,funsol[:,0],'k',label=u'Posición($m$)')
plt.plot(times,funsol[:,1],'r',label=u'Velocidad($m/s$)')
plt.legend(loc='best',fontsize=16)
plt.xlabel(u't/s',fontsize=20)
plt.title(u'Sistema de una partícula libre con $f(x) = Sin(x)$, sin ruido y markoviano.',fontsize=20)
plt.savefig('1')
plt.show()

# %%
# %matplotlib
fig = plt.figure(figsize=(15,10))
times=np.linspace(0,1.,100000)
pos, = plt.plot([],[],'k')
vel, = plt.plot([],[],'b')
plt.xlim(0.,1.)

alphas = np.arange(-15.,16.)
def animate(i):
    def f(Y,t):
        return np.array([Y[1],-alphas[i]*np.cos(Y[0])*Y[1]]) 
    funsol,others=odeint(f,[0.,1.],times,full_output=True)
    pos.set_data(times,funsol[:,0])
    vel.set_data(times,funsol[:,1])
    plt.ylim(0.,max(funsol[:,1])+0.1)
    return pos,vel

anim = animation.FuncAnimation(fig,animate,30,interval=500,blit=False,repeat_delay=1000)
plt.show()
# Out:
# Using matplotlib backend: Qt4Agg

# %%
# %matplotlib inline
alpha = 100.
def f(Y,t):
    return np.array([Y[1],-2*alpha*Y[0]*Y[1]]) 

times=np.linspace(0,.1,10000)
funsol,others=odeint(f,[0.,1.],times,full_output=True)

plt.figure(figsize=(15,10))
plt.plot(times,funsol[:,0])
plt.plot(times,funsol[:,1])
plt.show()

# %%
# %matplotlib
fig = plt.figure(figsize=(15,10))
times=np.linspace(0,.1,10000)
pos, = plt.plot([],[],'k')
#vel, = plt.plot([],[],'b')
plt.xlim(0.,.1)

alphas = np.arange(-100.,200.)
def animate(i):
    def f(Y,t):
        return np.array([Y[1],-2*alphas[i]*Y[0]*Y[1]]) 
    funsol,others=odeint(f,[0.,1.],times,full_output=True)
    pos.set_data(times,funsol[:,0])
    #vel.set_data(times,funsol[:,1])
    plt.ylim(0.,max(funsol[:,0])+0.01)
    return pos,

anim = animation.FuncAnimation(fig,animate,np.arange(0,500,2),interval=10,blit=False,repeat_delay=1000)
plt.show()
# Out:
# Using matplotlib backend: Qt4Agg

# %%
# %matplotlib inline
mass = 1.
alpha = 1.
def f(Y,t):
    return np.array([Y[1],-alpha*np.cos(Y[0])*Y[1] + (1/mass)*np.cos(Y[0])*np.cos(t)]) 

times=np.linspace(0,490.,1000000)
funsol,others=odeint(f,[0.,0.],times,full_output=True)

plt.figure(figsize=(15,10))
plt.plot(times,funsol[:,0],'k',label=u'Posición($m$)')
plt.plot(times,funsol[:,1],'r',label=u'Velocidad($m/s$)')
plt.legend(loc='best',fontsize=20)
plt.xlabel(u't/s',fontsize=20)
plt.title(u'Sistema de una partícula libre con $f(x) = Sin(x)$, ruido  sinusoidal y markoviano.',fontsize=20)
plt.savefig('2')
plt.show()

# %%
# %matplotlib
fig = plt.figure(figsize=(15,10))
times=np.linspace(0,50.,100000)
mass = 1.
pos, = plt.plot([],[],'k')
#vel, = plt.plot([],[],'b')
plt.xlim(0.,50.)

alphas = np.linspace(-15.,10.,100)
def animate(i):
    def f(Y,t):
        return np.array([Y[1],-alphas[i]*np.cos(Y[0])*Y[1] + (1./mass)*np.cos(Y[0])*np.cos(t)]) 
    funsol,others=odeint(f,[0.,0.],times,full_output=True)
    pos.set_data(times,funsol[:,0])
    #vel.set_data(times,funsol[:,1])
    plt.ylim(min(funsol[:,0])-0.1,max(funsol[:,0])+0.1)
    return pos
plt.axis('off')
anim = animation.FuncAnimation(fig,animate,np.arange(0,100,4),interval=1500,blit=False,repeat_delay=1000)
plt.show()
# Out:
# Using matplotlib backend: Qt4Agg

# %%
# %matplotlib inline
mass = 1.
alpha = 1.
def f(Y,t):
    return np.array([Y[1],-alpha*np.cos(Y[0])*Y[1] + (1/mass)*np.cos(Y[0])*np.sin(t)]) 

times=np.linspace(0,350.,100000)
funsol,others=odeint(f,[0.,0.],times,full_output=True)

plt.figure(figsize=(15,10))
plt.plot(times,funsol[:,0],'k',label=u'Posición')
plt.plot(times,funsol[:,1],'r',label=u'Velocidad')
plt.xlabel(u't/s',fontsize=20)
plt.legend(loc='best',fontsize=16)
plt.title(u'Sistema de una partícula libre con $f(x) = Sin(x)$, ruido sinusoidal y markoviano.',fontsize=20)
plt.savefig('3')
plt.show()

# %%
# %matplotlib
fig = plt.figure(figsize=(15,10))
times=np.linspace(0,50.,100000)
mass = 0.1
pos, = plt.plot([],[],'k')
#vel, = plt.plot([],[],'b')
plt.xlim(0.,50.)

alphas = np.linspace(-15.,15.,100)
def animate(i):
    def f(Y,t):
        return np.array([Y[1],-alphas[i]*np.cos(Y[0])*Y[1] + (1./mass)*np.cos(Y[0])*np.sin(t)]) 
    funsol,others=odeint(f,[0.,0.],times,full_output=True)
    pos.set_data(times,funsol[:,0])
    #vel.set_data(times,funsol[:,1])
    plt.ylim(min(funsol[:,0])-0.1,max(funsol[:,0])+0.1)
    return pos
#plt.axis('off')
anim = animation.FuncAnimation(fig,animate,np.arange(0,100,4),interval=1500,blit=False,repeat_delay=1000)
plt.show()
# Out:
# Using matplotlib backend: Qt4Agg

# %%
# %matplotlib inline
mass = 1.
alpha = 1.
def f(Y,t):
    return np.array([Y[1],-alpha*np.cos(Y[0])*Y[1] + (1/mass)*np.cos(Y[0])*np.exp(t)]) 

times=np.linspace(0,10.,100000)
funsol,others=odeint(f,[0.,0.],times,full_output=True)

plt.figure(figsize=(15,10))
plt.plot(times,funsol[:,0],'k',label=u'Posición')
plt.plot(times,funsol[:,1],'r',label=u'Velocidad')
plt.xlabel(u't/s',fontsize=20)
plt.legend(loc='best',fontsize=16)
plt.title(u'Sistema de una partícula libre con $f(x) = Sin(x)$, ruido exponencial y markoviano.',fontsize=20)
plt.savefig('4')
plt.show()

# %%
# %matplotlib inline
mass = 1.
alpha = 1.
def f(Y,t):
    return np.array([Y[1],-alpha*np.cos(Y[0])*Y[1] + (1/mass)*np.cos(Y[0])*np.exp(-t)]) 

times=np.linspace(0,15.,100000)
funsol,others=odeint(f,[0.,0.],times,full_output=True)

plt.figure(figsize=(15,10))
plt.plot(times,funsol[:,0],'k',label=u'Posición')
plt.plot(times,funsol[:,1],'r',label=u'Velocidad')
plt.xlabel(u't/s',fontsize=20)
plt.legend(loc='best',fontsize=16)
plt.title(u'Sistema de una partícula libre con $f(x) = Sin(x)$, con ruido exponencial y markoviano.',fontsize=20)
plt.savefig('5')
plt.show()

# %%
# %matplotlib
fig = plt.figure(figsize=(15,10))
times=np.linspace(0,15.,100000)
mass = 1.
pos, = plt.plot([],[],'k')
#vel, = plt.plot([],[],'b')
plt.xlim(0.,15.)

alphas = np.linspace(-1.,1.,100)
def animate(i):
    def f(Y,t):
        return np.array([Y[1],-alphas[i]*np.cos(Y[0])*Y[1] + (1/mass)*np.cos(Y[0])*np.exp(t)]) 
    funsol,others=odeint(f,[0.,0.],times,full_output=True)
    pos.set_data(times,funsol[:,0])
    #vel.set_data(times,funsol[:,1])
    plt.ylim(min(funsol[:,0])-0.1,max(funsol[:,0])+0.1)
    return pos

anim = animation.FuncAnimation(fig,animate,np.arange(0,100,10),interval=1,blit=False,repeat_delay=1000)
plt.show()
# Out:
# Using matplotlib backend: Qt4Agg

# %%
# %matplotlib inline
mass = 1.
omega = 1.
alpha = .1
def f1(Y,t):
    return np.array([Y[1],-(omega**2)*Y[0] - alpha*np.cos(Y[0])*Y[1] + (1/mass)*np.cos(Y[0])*np.exp(-t)]) 

def f2(Y,t):
    return np.array([Y[1],-(omega**2)*Y[0] - alpha*np.cos(Y[0])*Y[1]]) 

times=np.linspace(0,70.,100000)
funsol1,others1=odeint(f1,[0.,1.],times,full_output=True)
funsol2,others2=odeint(f2,[0.,1.],times,full_output=True)

plt.figure(figsize=(15,10))
plt.plot(times,funsol1[:,0],'k',label=u'Posición de un oscilador con ruido')
plt.plot(times,funsol2[:,0],'r',label=u'Posición de un oscilador amortiguado')
plt.xlabel(u't/s',fontsize=20)
plt.legend(loc='best',fontsize=16)
plt.title(u'Oscilador armónico con ruido y amortiguado.',fontsize=20)
plt.savefig('6')
plt.show()

# %%
# %matplotlib
fig = plt.figure(figsize=(15,10))
times=np.linspace(0,15.,100000)
mass = 1.
omega = 1.
pos, = plt.plot([],[],'k')
vel, = plt.plot([],[],'b')
plt.xlim(0.,15.)

alphas = np.linspace(-.4,.4,100)
def animate(i):
    def f1(Y,t):
        return np.array([Y[1],-alphas[i]*np.cos(Y[0])*Y[1] - (omega**2)*Y[0] + (1./mass)*np.cos(Y[0])*np.exp(t)]) 

    def f2(Y,t):
        return np.array([Y[1],-alphas[i]*Y[1] - (omega**2)*Y[0] + (1./mass)*np.cos(Y[0])*np.exp(t)]) 

    funsol1,others1=odeint(f1,[0.,1.],times,full_output=True)
    funsol2,others2=odeint(f2,[0.,1.],times,full_output=True)
    pos.set_data(times,funsol1[:,0])
    vel.set_data(times,funsol2[:,0])
    plt.ylim(min(funsol2[:,0])-0.1,max(funsol2[:,0])+0.1)
    return pos,vel

anim = animation.FuncAnimation(fig,animate,100,interval=1,blit=False,repeat_delay=1000)
plt.show()
# Out:
# Using matplotlib backend: Qt4Agg
